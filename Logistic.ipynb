# %% [markdown]
# Logistic Regression

# %%
# Price Prediction using Ridge Regression (text-based)

# %%
# %pip install seaborn

# --- 1. Import libraries ---
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score
import joblib
import os
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# --- 2. Load dataset ---
df = pd.read_csv("train.csv")

print("Dataset shape:", df.shape)
print(df.head(), "\n")
# Out:
# Dataset shape: (75000, 4)
#    sample_id                                    catalog_content  \
# 0      33127  Item Name: La Victoria Green Taco Sauce Mild, ...
# 1     198967  Item Name: Salerno Cookies, The Original Butte...
# 2     261251  Item Name: Bear Creek Hearty Soup Bowl, Creamy...
# 3      55858  Item Name: Judee’s Blue Cheese Powder 11.25 oz...
# 4     292686  Item Name: kedem Sherry Cooking Wine, 12.7 Oun...
#
#                                           image_link  price
# 0  https://m.media-amazon.com/images/I/51mo8htwTH...   4.89
# 1  https://m.media-amazon.com/images/I/71YtriIHAA...  13.12
# 2  https://m.media-amazon.com/images/I/51+PFEe-w-...   1.97
# 3  https://m.media-amazon.com/images/I/41mu0HAToD...  30.34
# 4  https://m.media-amazon.com/images/I/41sA037+Qv...  66.49

# %%
# --- 3. Features and target ---
X_text = df["catalog_content"]
y = df["price"]

# %%
# --- 4. Split data ---
X_train, X_test, y_train, y_test = train_test_split(X_text, y, test_size=0.2, random_state=42)

# %%
# --- 5. Convert text to TF-IDF features ---
vectorizer = TfidfVectorizer(max_features=5000, stop_words='english')
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
# --- 6. Train a regression model ---
model = Ridge(alpha=1.0)  # regularized linear regression
model.fit(X_train_tfidf, y_train)
# Out:
# Ridge()

# %%
# --- 7. Evaluate ---
y_pred = model.predict(X_test_tfidf)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)


print(f"✅ Model trained successfully!")
print(f"Mean Squared Error: {mse:.2f}")
print(f"R² Score: {r2:.3f}")
# Out:
# ✅ Model trained successfully!
# Mean Squared Error: 1167.42
# R² Score: 0.226

# %%
# --- 8. Save model and vectorizer ---
os.makedirs("models", exist_ok=True)
joblib.dump(model, "models/price_model.joblib")
joblib.dump(vectorizer, "models/tfidf_vectorizer.joblib")

print("\nModel and vectorizer saved in 'models/' directory.")
# Out:
# Model and vectorizer saved in 'models/' directory.

# %%
# --- 9. Predict for test.csv ---
test_df = pd.read_csv("test.csv")
X_test_text = test_df["catalog_content"]
X_test_tfidf_new = vectorizer.transform(X_test_text)
predictions = model.predict(X_test_tfidf_new)

test_df["predicted_price"] = predictions
test_df.to_csv("predicted_prices.csv", index=False)

print("\n✅ Predictions saved to 'predicted_prices.csv'")
# Out:
# ✅ Predictions saved to 'predicted_prices.csv'

# %%
# Plot predicted vs actual prices using matplotlib / seaborn (Python)

# y_test and y_pred are defined in earlier cells; plot true vs predicted prices
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, s=15, alpha=0.6)
# add a regression (fit) line
sns.regplot(x=y_test, y=y_pred, scatter=False, color='green', ci=None)
# add diagonal reference line (perfect prediction)
min_val = min(y_test.min(), y_pred.min())
max_val = max(y_test.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], "r--", linewidth=1)

plt.xlabel("True Price (y_test)")
plt.ylabel("Predicted Price (y_pred)")
plt.title("True vs Predicted Prices")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Plot predicted vs actual prices using matplotlib / seaborn (Python)
#       2 import matplotlib.pyplot as plt
# ----> 3 import seaborn as sns
#       5 # y_test and y_pred are defined in earlier cells; plot true vs predicted prices
#       6 plt.figure(figsize=(8, 6))
#
# ModuleNotFoundError: No module named 'seaborn'
